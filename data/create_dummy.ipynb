# %%
import pandas as pd

age = pd.read_csv("age.csv")
labels = pd.read_csv("labels.csv")
sra_to_bioprojects = pd.read_csv("sra_to_bioproject.csv")
df = pd.read_csv("getmm_combat_seq_no_outliers_and_singles_gene_expression.csv")

# %%
labels_100 = labels.iloc[:100, :]

# %%
age_100 = age.iloc[:100, :]
df_100 = df.iloc[:100, :]

# %%
sra_to_bioprojects_100 = sra_to_bioprojects.iloc[:100, :]

# %%
sra_to_bioprojects_100.to_csv("sra_to_bioproject_dummy.csv", index=False)
age_100.to_csv("age_dummy.csv", index=False)
df_100.to_csv("gene_exp_dummy.csv", index=False)
labels_100.to_csv("labels_dummy.csv", index=False)
